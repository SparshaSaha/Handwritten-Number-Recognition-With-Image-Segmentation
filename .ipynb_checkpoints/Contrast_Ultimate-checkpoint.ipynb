# %%
import scipy.io
import matplotlib.pyplot as pyplot
import matplotlib.cm as cm
import numpy as np
from PIL import Image, ImageEnhance

# %%
img=scipy.misc.imread('my_img.jpg')
img=img[:,:,0]
mini=2000
maxi=0
pyplot.imshow(img,cmap=cm.gray)
pyplot.show()
img=img/255.0

for i in img:
    for j in i:
        if j>maxi:
            maxi=j
        if j<mini:
            mini=j
thresh=(mini+maxi)/2.0
image_new=[]
flat=[]
for i in img:
    temp=[]
    for j in i:
        if j<thresh-0.2:
            temp.append(0.0)
        else:
            temp.append(1.0)
    image_new.append(temp)
image_new=np.matrix(image_new)
pyplot.imshow(image_new,cmap=cm.gray)

scipy.misc.imsave('temp.jpg', image_new)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
